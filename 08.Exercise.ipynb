# %% [markdown]
# # 08 ヒープとハッシュ: Heaps and Hashes

# %% [markdown]
# ## 課題
# 講義で紹介した`BinaryHeap`クラスをつかって、データの追加、削除によって、データを保持しているリストがどのように変化するかを確認しなさい。
#
# With the `BinaryHeap` class introduced in the lecture, observe how the list that holds the data changes with the addition and removal of data.

# %% [markdown]
# ## 課題
# 最大値を取り出すためのヒープを実装しなさい。
#
# Implement a heap for retrieving the maximum value.
